# %%
import c3s_lib

# %%
data_client = c3s_lib.DataClient(beacon_cache_url="https://beacon-era5.maris.nl", cds_key="98256e82-4de4-4cc1-8087-faebb5c2e4ae")
# Out:
# 2025-12-17 16:35:11,333 INFO [2025-12-03T00:00:00Z] To improve our C3S service, we need to hear from you! Please complete this very short [survey](https://confluence.ecmwf.int/x/E7uBEQ/). Thank you.
# Connected to: https://beacon-era5.maris.nl/ server successfully
# Beacon Version: 1.4.0

# %%
from datetime import datetime
time_range = (datetime(2020, 1, 1), datetime(2020, 1, 31))

ds = data_client.get_daily_data_xr(bbox=(0, 5,10,15), time_ranges=[time_range], variable="t2m")
# Out:
# Fetching data for range: 2020-01-01 00:00:00 - 2020-01-31 00:00:00
# Creating JSONQuery with from: FromTable(table='daily')
# Running query: {"output": {"format": {"nd_netcdf": {"dimension_columns": ["longitude", "latitude", "valid_time"]}}}, "select": [{"column": "longitude", "alias": null}, {"column": "latitude", "alias": null}, {"column": "valid_time", "alias": null}, {"column": "t2m", "alias": null}], "filters": [{"and": [{"column": "longitude", "gt_eq": 0.0, "lt_eq": null}, {"column": "longitude", "gt_eq": null, "lt_eq": 10.0}, {"column": "latitude", "gt_eq": 5, "lt_eq": null}, {"column": "latitude", "gt_eq": null, "lt_eq": 15}]}, {"column": "valid_time", "gt_eq": "2020-01-01T00:00:00.000000", "lt_eq": "2020-01-31T00:00:00.000000"}], "distinct": null, "sort_by": null, "limit": null, "offset": null, "from": "daily"}

# %%
ds
# Out:
# <xarray.Dataset> Size: 209kB
# Dimensions:     (time: 1, longitude: 41, latitude: 41, valid_time: 31)
# Coordinates:
#   * longitude   (longitude) float64 328B 0.0 0.25 0.5 0.75 ... 9.5 9.75 10.0
#   * latitude    (latitude) float64 328B 5.0 5.25 5.5 5.75 ... 14.5 14.75 15.0
#   * valid_time  (valid_time) datetime64[ns] 248B 2020-01-01 ... 2020-01-31
# Dimensions without coordinates: time
# Data variables:
#     t2m         (time, longitude, latitude, valid_time) float32 208kB 301.6 ....
