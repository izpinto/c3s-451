# %%
from c3s_lib import *

# %%
gdf = DataClient('your_cds_key').temperature_2m_mean((-10.0, -20.0, 30.0, 40.0), (datetime(2020, 1, 1), datetime(2020, 1, 2)))
# Out:
# 2025-07-21 12:31:34,948 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# {'product_type': 'reanalysis', 'variable': ['2m_temperature'], 'year': '2020', 'month': ['01'], 'day': ['01', '02'], 'daily_statistic': 'daily_mean', 'time_zone': 'utc+00:00', 'frequency': '1_hourly', 'area': [40.0, -10.0, -20.0, 30.0]}
# 2025-07-21 12:31:35,556 INFO Request ID is b1c1071b-4d71-4f44-a66c-1f8b6290ff3d
# 2025-07-21 12:31:35,650 INFO status has been updated to accepted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gdf = DataClient('88aafa2d-217e-4761-9016-e72011d11320').temperature_2m_mean((-10.0, -20.0, 30.0, 40.0), (datetime(2020, 1, 1), datetime(2020, 1, 2)))
#
# File c:\Maris-Git\c3s-451\library\c3s_lib\data.py:52, in DataClient.temperature_2m_mean(self, bbox, time_range)
# ...

# %%
gdf
# Out:
#       valid_time  latitude  longitude         t2m  number           geometry
# 0     2020-01-01      40.0     -10.00  285.689789       0     POINT (-10 40)
# 1     2020-01-01      40.0      -9.75  285.388428       0   POINT (-9.75 40)
# 2     2020-01-01      40.0      -9.50  285.193268       0    POINT (-9.5 40)
# 3     2020-01-01      40.0      -9.25  284.797699       0   POINT (-9.25 40)
# 4     2020-01-01      40.0      -9.00  283.912262       0      POINT (-9 40)
# ...          ...       ...        ...         ...     ...                ...
# 77597 2020-01-02     -20.0      29.00  299.549347       0     POINT (29 -20)
# 77598 2020-01-02     -20.0      29.25  299.351288       0  POINT (29.25 -20)
# 77599 2020-01-02     -20.0      29.50  298.901154       0   POINT (29.5 -20)
# 77600 2020-01-02     -20.0      29.75  299.184296       0  POINT (29.75 -20)
# 77601 2020-01-02     -20.0      30.00  299.702423       0     POINT (30 -20)
#
# [77602 rows x 6 columns]

# %%
fig = visualize_geo(gdf, 't2m', 'longitude', 'latitude', backend='plotly', zoom=1)
fig.show()
